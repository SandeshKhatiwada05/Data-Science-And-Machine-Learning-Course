# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading data

# %%
dataset = pd.read_csv("titanic_train.csv")

# %% [markdown]
# ### Loading head and tail

# %%
dataset.head() #by default top 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
dataset.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %% [markdown]
# ### Check dataset

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
dataset.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dataset.describe() #works only with numerical data not with categorical like names
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataset.describe(include=object) #now it shows categorical values
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
print(type(dataset['Age']))
dataset['Age'].unique()
# Out:
# <class 'pandas.core.series.Series'>
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %% [markdown]
# ### Approaches to solve the missing values

# %% [markdown]
# 1. Drop rows and columnn with missing value
# 2. Fill missing value with constant of missing value
# 3. Use of aggregated value ✔️
# 4. Fill the missing value with previous or next value
# 5. Algorithms ml can be used

# %% [markdown]
# ### Find missing value

# %%
#this gives boolean indexing
dataset.isna()
#dataset.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#this gives number of missing
dataset.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Check repeatition of a column
print(dataset['Age'].value_counts())
print("\n\n\n",dataset['Sex'].value_counts())
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64
#
#
#
#  Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ##### Datatypes of data

# %%
dataset.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Filtering rows

# %%
dataset['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
survived_passengers = dataset[dataset['Survived'] == 1]

# %%
survived_passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#fare value grateer than 50
fare_greater_than_50 =  dataset[dataset['Fare'] > 50]
fare_greater_than_50
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Selecting colums

# %%
data_with_selected_columns = survived_passengers[['Name', 'Age']]
data_with_selected_columns
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 889                              Behr, Mr. Karl Howell  26.0
#
# [342 rows x 2 columns]

# %%
data_with_selected_columns = survived_passengers[['Name', 'Age', 'Sex']]
data_with_selected_columns
# Out:
#                                                   Name   Age     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# ..                                                 ...   ...     ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0  female
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  female
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0  female
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 889                              Behr, Mr. Karl Howell  26.0    male
#
# [342 rows x 3 columns]

# %%
sorted_data = data_with_selected_columns.sort_values(by=['Age'])
sorted_data
# Out:
#                                              Name   Age     Sex
# 803               Thomas, Master. Assad Alexander  0.42    male
# 755                     Hamalainen, Master. Viljo  0.67    male
# 644                        Baclini, Miss. Eugenie  0.75  female
# 469                 Baclini, Miss. Helene Barbara  0.75  female
# 831               Richards, Master. George Sibley  0.83    male
# ..                                            ...   ...     ...
# 727                      Mannion, Miss. Margareth   NaN  female
# 740                   Hawksford, Mr. Walter James   NaN    male
# 828                  McCormack, Mr. Thomas Joseph   NaN    male
# 839                          Marechal, Mr. Pierre   NaN    male
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)   NaN  female
#
# [342 rows x 3 columns]

# %%
sorted_data_descending = data_with_selected_columns.sort_values(by=['Age'], ascending=False, na_position='first')
sorted_data_descending
# Out:
#                                                Name   Age     Sex
# 17                     Williams, Mr. Charles Eugene   NaN    male
# 19                          Masselmani, Mrs. Fatima   NaN  female
# 28                    O'Dwyer, Miss. Ellen "Nellie"   NaN  female
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)   NaN  female
# 32                         Glynn, Miss. Mary Agatha   NaN  female
# ..                                              ...   ...     ...
# 831                 Richards, Master. George Sibley  0.83    male
# 644                          Baclini, Miss. Eugenie  0.75  female
# 469                   Baclini, Miss. Helene Barbara  0.75  female
# 755                       Hamalainen, Master. Viljo  0.67    male
# 803                 Thomas, Master. Assad Alexander  0.42    male
#
# [342 rows x 3 columns]

# %% [markdown]
# #### Handling missing value

# %%
dataset.shape
# Out:
# (891, 12)

# %%
#we drop the data which has nan, this is not an aapropriate 
dataset_dropped_nan = dataset.dropna()
dataset_dropped_nan.shape
# Out:
# (183, 12)
