# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"D:\Github\Data-Science-And-Machine-Learning-Course\DSML Class Orchid\Day 4\titanic_train.csv")

# %%
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dataset["Age"].fillna(dataset["Age"].mean(), inplace=True)
# Out:
# C:\Users\Sandesh Khatiwada\AppData\Local\Temp\ipykernel_9012\824851362.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Age"].fillna(dataset["Age"].mean(), inplace=True)

# %%
dataset["Age"].isna().sum()
# Out:
# 0

# %%
min_age = dataset["Age"].min()
min_age
# Out:
# 0.42

# %%
max_age = dataset["Age"].max()
max_age
# Out:
# 80.0

# %%
dataset["Age"].sort_values() #sorts value from lowest to highest
# Out:
# 803     0.42
# 755     0.67
# 644     0.75
# 469     0.75
# 831     0.83
#        ...
# 116    70.50
# 96     71.00
# 493    71.00
# 851    74.00
# 630    80.00
# Name: Age, Length: 891, dtype: float64

# %%
age_range = dataset["Age"].max() - dataset["Age"].min() #difference between max and min
age_range
# Out:
# 79.58

# %%
sns.histplot(x=dataset["Age"], bins=8)
plt.axvline(x = min_age, color="black", label="min_age")
plt.axvline(x=max_age, color="green", label="max_age")
plt.axvline(x=age_range, color="red", label="range")
plt.legend()
plt.show()

# %% [markdown]
# ### Mean Absolute Deviation (MAD)

# %%
names = ["Raj", "Tina", "Mina", "Samyog", "Birsky", "YB"]

scores_a = [75, 65, 73, 68, 72, 67]
scores_b = [90, 47, 43, 96, 93, 51]

# Plot both sections
plt.plot(names, scores_a, color="black", marker="o", label="Section A")
plt.plot(names, scores_b, color="red", marker="o", label="Section B")

plt.legend()

# Compute means
mean_a = np.mean(scores_a)
mean_b = np.mean(scores_b)

print("Mean are same")
print("Mean of Section A:", mean_a)
print("Mean of Section B:", mean_b)
# Out:
# Mean are same
# Mean of Section A: 70.0
# Mean of Section B: 70.0

# %%
#for scattered instead of normal plots
scores_a = [75, 65, 73, 68, 72, 76]
scores_b = [90, 47, 43, 96, 93, 51]
no = [1,2,3,4,5,6]

plt.figure(figsize=(9,3))
plt.scatter(scores_a, no, color="red", label="Section-A")
plt.scatter(scores_b, no, color="green", label="Section-B")
plt.axvline(x=mean_a, color="black", label="mean")

plt.legend()

# %% [markdown]
# ### Mean Absolute Deviation Numerically (MAD)

# %% [markdown]
# ![image.png](attachment:5291ccaa-7d8c-44d5-9180-84487595c7a1.png)

# %%
#Subtracting from mean
scores_a = np.array([75, 65, 73, 68, 72, 76])
scores_b = np.array([90, 47, 43, 96, 93, 51])

# Subtracting mean
subtracted_a = scores_a - scores_a.mean()
subtracted_b = scores_b - scores_b.mean()

MAD_a = (np.sum(abs(subtracted_a))/len(subtracted_a)) 
MAD_b = (np.sum(abs(subtracted_b))/len(subtracted_b))
print(MAD_a, " , ",MAD_b)
# Out:
# 3.3333333333333335  ,  23.0
