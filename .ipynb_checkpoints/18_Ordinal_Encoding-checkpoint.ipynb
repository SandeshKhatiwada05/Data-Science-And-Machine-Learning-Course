# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ### Using Sklearn

# %%
sizes = ["S", "M", "L", "XL", "XXL", "XXXL", "XXS"]
df = pd.DataFrame(sizes, columns=["Sizes"])
df
# Out:
#   Sizes
# 0     S
# 1     M
# 2     L
# 3    XL
# 4   XXL
# 5  XXXL
# 6   XXS

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordered_size = [["XXS" ,"S", "M", "L", "XL", "XXL", "XXXL"]]
oe = OrdinalEncoder(categories=ordered_size)#categories = auto, sets categories in alphabetical order

# %%
#fit transform
oe.fit(df[["Sizes"]])
# Out:
# OrdinalEncoder(categories=[['XXS', 'S', 'M', 'L', 'XL', 'XXL', 'XXXL']])

# %%
df["Size_ordinal_enc"] = oe.transform(df[["Sizes"]])

# %%
df
# Out:
#   Sizes  Size_ordinal_enc
# 0     S               1.0
# 1     M               2.0
# 2     L               3.0
# 3    XL               4.0
# 4   XXL               5.0
# 5  XXXL               6.0
# 6   XXS               0.0

# %% [markdown]
# ### Using Map

# %%
ord_data_map = {"XXS":0 ,"S":1, "M":2, "L":3, "XL":4, "XXL":5, "XXXL":6}

# %%
df["Sizes using Map"] = df["Sizes"].map(ord_data_map)

# %%
df
# Out:
#   Sizes  Size_ordinal_enc  Sizes using Map
# 0     S               1.0                1
# 1     M               2.0                2
# 2     L               3.0                3
# 3    XL               4.0                4
# 4   XXL               5.0                5
# 5  XXXL               6.0                6
# 6   XXS               0.0                0

# %% [markdown]
# ### Using dataset to check ordinal encoding

# %%
dataset = pd.read_csv(r"D:\Github\Data-Science-And-Machine-Learning-Course\Datasets\Loan.csv")

# %%
dataset.head(50)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
dataset["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
property_area_category = [['Rural', 'Semiurban', 'Urban']]
oe_db = OrdinalEncoder(categories=property_area_category)

# %%
fitted_property = oe_db.fit(dataset[["Property_Area"]])
fitted_property
# Out:
# OrdinalEncoder(categories=[['Rural', 'Semiurban', 'Urban']])

# %%
dataset["Property_ordinal_encoded"] = oe_db.transform(dataset[["Property_Area"]])
dataset["Property_ordinal_encoded"]
# Out:
# 0      2.0
# 1      0.0
# 2      2.0
# 3      2.0
# 4      2.0
#       ...
# 609    0.0
# 610    0.0
# 611    2.0
# 612    2.0
# 613    1.0
# Name: Property_ordinal_encoded, Length: 614, dtype: float64

# %%
dataset.head(7)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# ...

# %%
dataset["Property_ordinal_encoded"].unique()
# Out:
# array([2., 0., 1.])
