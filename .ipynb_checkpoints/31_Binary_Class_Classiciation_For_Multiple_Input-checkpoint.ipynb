# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"D:\Github\Data-Science-And-Machine-Learning-Course\Datasets\Fish_polynomial_Data with multiple features.csv")

# %%
dataset.head(3)
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961

# %%
sns.scatterplot(data=dataset, x="Weight" ,y="Species", hue="Species")
# Out:
# <Axes: xlabel='Weight', ylabel='Species'>
