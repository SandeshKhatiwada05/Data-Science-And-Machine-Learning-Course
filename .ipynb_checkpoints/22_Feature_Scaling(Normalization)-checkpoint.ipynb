# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"D:\Github\Data-Science-And-Machine-Learning-Course\Datasets\Loan.csv")

# %%
dataset.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#lets normalize Coapplicant Income
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()

# %%
ms.fit(dataset[["CoapplicantIncome"]])
# Out:
# MinMaxScaler()

# %%
new_table_for_CoapplicantIncome = pd.DataFrame(dataset["CoapplicantIncome"], columns=["CoapplicantIncome"])
new_table_for_CoapplicantIncome
# Out:
#      CoapplicantIncome
# 0                  0.0
# 1               1508.0
# 2                  0.0
# 3               2358.0
# 4                  0.0
# ..                 ...
# 609                0.0
# 610                0.0
# 611              240.0
# 612                0.0
# 613                0.0
#
# [614 rows x 1 columns]

# %%
new_table_for_CoapplicantIncome["Coaaplicant_Min_Max"] = ms.transform(dataset[["CoapplicantIncome"]])
new_table_for_CoapplicantIncome
# Out:
#      CoapplicantIncome  Coaaplicant_Min_Max
# 0                  0.0             0.000000
# 1               1508.0             0.036192
# 2                  0.0             0.000000
# 3               2358.0             0.056592
# 4                  0.0             0.000000
# ..                 ...                  ...
# 609                0.0             0.000000
# 610                0.0             0.000000
# 611              240.0             0.005760
# 612                0.0             0.000000
# 613                0.0             0.000000
#
# [614 rows x 2 columns]
