# %%
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv(r"D:\Github\Data-Science-And-Machine-Learning-Course\Datasets\Loan.csv")

# %%
dataset.shape
# Out:
# (614, 13)

# %%
dataset.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
dataset.isna().sum().sum()
# Out:
# np.int64(149)

# %%
sns.heatmap(dataset.isna())
# Out:
# <Axes: >

# %% [markdown]
# ### Dropping column with the max missing value

# %%
dataset.drop(columns=["Credit_History"], inplace=True)

# %%
dataset.shape
# Out:
# (614, 12)

# %%
dataset.isna().sum().sum()
# Out:
# np.int64(99)

# %%
sns.heatmap(dataset.isna())
# Out:
# <Axes: >
