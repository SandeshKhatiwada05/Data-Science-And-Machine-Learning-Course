# %%
import scipy.stats as st

# %%
st.norm.ppf(0.45) #finds value of z
# Out:
# np.float64(-0.12566134685507402)

# %%
st.norm.ppf(0.95)
# Out:
# np.float64(1.6448536269514722)

# %% [markdown]
# ### Question
# ![image.png](attachment:05ba6490-9a1e-4f19-a1ad-cd44f60bbc1e.png)

# %%
population_mean_μ = 82 
population_standard_deviation_σ = 20

sample_mean_x̄ = 90 
sample_number_n = 81

alpha_α = 0.05

# %% [markdown]
# ![image.png](attachment:8986e6e2-ce73-4605-abcf-4c8b4c12b4ba.png)

# %%
import math
z_calulated = (sample_mean_x̄-population_mean)/(population_standard_deviation_σ/(math.sqrt(sample_number)))
print("z calculate is: ", z_calulated)
# Out:
# z calculate is:  3.5999999999999996

# %%
z_tabulated = st.norm.ppf(alpha_α)
print("z tabulate is : ", z_tabulated)
# Out:
# z tabulate is :  -1.6448536269514729

# %%
if z_calulated > z_tabulated:
    print("Alternate hypthoesis (H1) is accepted")
else:
    print("Null hypthoesis (H0) is accepted")
# Out:
# Alternate hypthoesis (H1) is accepted
