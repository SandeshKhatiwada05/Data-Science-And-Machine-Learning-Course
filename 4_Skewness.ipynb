# %% [markdown]
# ### Skewness

# %% [markdown]
# ![image.png](attachment:8cce4b83-1025-4923-8256-f2cb12d6098d.png)

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv(r"D:\Github\Data-Science-And-Machine-Learning-Course\DSML Class Orchid\Day 4\titanic_train.csv")

# %%
dataset["Age"].fillna(dataset["Age"].mean(), inplace= True)
# Out:
# C:\Users\Sandesh Khatiwada\AppData\Local\Temp\ipykernel_16308\2354803512.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Age"].fillna(dataset["Age"].mean(), inplace= True)

# %%
print("Null in Age: ", dataset["Age"].isna().sum())
# Out:
# Null in Age:  0

# %% [markdown]
# #### Finding mean, median and mode

# %%
mean_age = np.mean(dataset["Age"])
median_age = np.median(dataset["Age"])
mode_age = dataset["Age"].mode()[0]

# %%
print("Mean: ", mean_age)
print("Median: ", median_age)
print("Mode: ", mode_age)
# Out:
# Mean:  29.69911764705882
# Median:  29.69911764705882
# Mode:  29.69911764705882

# %% [markdown]
# ### Finding skewness

# %%
if mean_age<median_age and median_age<mode_age and mean_age<mode_age:
    print("It is negatively skewed")
if mean_age==mode_age==median_age:
    print("It is not skewed")
if mode_age<mean_age and mode_age<median_age and median_age<mean_age:
    print("It is postively skewed")
# Out:
# It is not skewed

# %%
#or directly more accurate one than classsical way
dataset["Age"].skew()
# Out:
# 0.4344880940129925

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(dataset["Age"], bins=20, kde=True) #Kernel Density Estimate will be drawn along with your histogram.
plt.axvline(dataset["Age"].mean(), color="green", label="Mean")
plt.axvline(dataset["Age"].median(), color="pink", label="Median")
plt.axvline(dataset["Age"].mode()[0], color="red", label="Mode")
plt.legend()
plt.show()

# %%
#check by creating own data
data = np.random.normal(1,100, 100)

# %%
df = pd.DataFrame({"x": data})

# %%
df["x"].skew()
# Out:
# 0.35096629080010405

# %%
sns.histplot(x="x", data=df)
# Out:
# <Axes: xlabel='x', ylabel='Count'>
