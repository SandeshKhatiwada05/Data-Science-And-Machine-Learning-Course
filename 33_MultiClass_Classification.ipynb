# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# try this tom
# ![image.png](attachment:e97cd822-f05d-4686-a524-68b7e294df92.png)
# ![image.png](attachment:ea0e9789-9364-494c-899e-73b8598ddb65.png)
